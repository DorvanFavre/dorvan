# %% [markdown]
# # Cartpole

# %%
# !pip install stable-baselines3
# Out:
# /bin/bash: /home/dorvan/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/bin/pip: /home/dorvan/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/Learn_Jetson/jetsonEnv/bin/python: bad interpreter: No such file or directory

# %%
import gymnasium as gym
import stable_baselines3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import gymnasium as gym
# ----> 2 import stable_baselines3
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/__init__.py:3
#       1 import os
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/a2c/__init__.py:1
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       4 __all__ = ["CnnPolicy", "MlpPolicy", "MultiInputPolicy", "A2C"]
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/a2c/a2c.py:7
#       4 from gymnasium import spaces
#       5 from torch.nn import functional as F
# ----> 7 from stable_baselines3.common.buffers import RolloutBuffer
#       8 from stable_baselines3.common.on_policy_algorithm import OnPolicyAlgorithm
#       9 from stable_baselines3.common.policies import ActorCriticCnnPolicy, ActorCriticPolicy, BasePolicy, MultiInputActorCriticPolicy
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:16
#       9 from stable_baselines3.common.preprocessing import get_action_dim, get_obs_shape
#      10 from stable_baselines3.common.type_aliases import (
#      11     DictReplayBufferSamples,
#      12     DictRolloutBufferSamples,
#      13     ReplayBufferSamples,
#      14     RolloutBufferSamples,
#      15 )
# ---> 16 from stable_baselines3.common.utils import get_device
#      17 from stable_baselines3.common.vec_env import VecNormalize
#      19 try:
#      20     # Check memory used by replay buffer when possible
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/common/utils.py:24
#      21 except ImportError:
#      22     SummaryWriter = None  # type: ignore[misc, assignment]
# ---> 24 from stable_baselines3.common.logger import Logger, configure
#      25 from stable_baselines3.common.type_aliases import GymEnv, Schedule, TensorDict, TrainFreq, TrainFrequencyUnit
#      28 def set_random_seed(seed: int, using_cuda: bool = False) -> None:
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/stable_baselines3/common/logger.py:11
#       8 from io import TextIOBase
#       9 from typing import Any, Dict, List, Mapping, Optional, Sequence, TextIO, Tuple, Union
# ---> 11 import matplotlib.figure
#      12 import numpy as np
#      13 import pandas
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/__init__.py:967
#     961     return config
#     964 # When constructing the global instances, we need to perform certain updates
#     965 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     966 # triggering resolution of _auto_backend_sentinel.
# --> 967 rcParamsDefault = _rc_params_in_file(
#     968     cbook._get_data_path("matplotlibrc"),
#     969     # Strip leading comment.
#     970     transform=lambda line: line[1:] if line.startswith("#") else line,
#     971     fail_on_error=True)
#     972 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
#     973 # Normally, the default matplotlibrc file contains *no* entry for backend (the
#     974 # corresponding line starts with ##, not #; we fill on _auto_backend_sentinel
#     975 # in that case.  However, packagers can set a different default backend
#     976 # (resulting in a normal `#backend: foo` line) in which case we should *not*
#     977 # fill in _auto_backend_sentinel.
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/__init__.py:901, in _rc_params_in_file(fname, transform, fail_on_error)
#     899 if key in rcsetup._validators:
#     900     if fail_on_error:
# --> 901         config[key] = val  # try to convert to proper type or raise
#     902     else:
#     903         try:
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/__init__.py:736, in RcParams.__setitem__(self, key, val)
#     734             return
#     735 try:
# --> 736     cval = self.validate[key](val)
#     737 except ValueError as ve:
#     738     raise ValueError(f"Key {key}: {ve}") from None
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/rcsetup.py:342, in validate_color(s)
#     339         if is_color_like(stmp):
#     340             return stmp
# --> 342 if is_color_like(s):
#     343     return s
#     345 # If it is still valid, it must be a tuple (as a string from matplotlibrc).
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/colors.py:227, in is_color_like(c)
#     225     return True
#     226 try:
# --> 227     to_rgba(c)
#     228 except (TypeError, ValueError):
#     229     return False
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/matplotlib/colors.py:336, in _to_rgba_no_colorcycle(c, alpha)
#     334     raise ValueError("'alpha' must be between 0 and 1, inclusive")
#     335 orig_c = c
# --> 336 if c is np.ma.masked:
#     337     return (0., 0., 0., 0.)
#     338 if isinstance(c, str):
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/__init__.py:346, in __getattr__(attr)
#     338     public_symbols -= {
#     339         "core", "matrixlib",
#     340         # These were moved in 1.25 and may be deprecated eventually:
#     341         "ModuleDeprecationWarning", "VisibleDeprecationWarning",
#     342         "ComplexWarning", "TooHardError", "AxisError"
#     343     }
#     344     return list(public_symbols)
# --> 346 # Pytest testing
#     347 from numpy._pytesttester import PytestTester
#     348 test = PytestTester(__name__)
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/ma/__init__.py:42
#       1 """
#       2 =============
#       3 Masked Arrays
#    (...)
#      40
#      41 """
# ---> 42 from . import core
#      43 from .core import *
#      45 from . import extras
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/ma/core.py:36
#      34 from numpy import ndarray, amax, amin, iscomplexobj, bool_, _NoValue
#      35 from numpy import array as narray
# ---> 36 from numpy.lib.function_base import angle
#      37 from numpy.compat import (
#      38     getargspec, formatargspec, long, unicode, bytes
#      39     )
#      40 from numpy import expand_dims
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/lib/function_base.py:25
#      23 from numpy.core import overrides
#      24 from numpy.core.function_base import add_newdoc
# ---> 25 from numpy.lib.twodim_base import diag
#      26 from numpy.core.multiarray import (
#      27     _insert, add_docstring, bincount, normalize_axis_index, _monotonicity,
#      28     interp as compiled_interp, interp_complex as compiled_interp_complex
#      29     )
#      30 from numpy.core.umath import _add_newdoc_ufunc as add_newdoc_ufunc
#
# File ~/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/lib/twodim_base.py:15
#      13 from numpy.core import overrides
#      14 from numpy.core import iinfo
# ---> 15 from numpy.lib.stride_tricks import broadcast_to
#      18 __all__ = [
#      19     'diag', 'diagflat', 'eye', 'fliplr', 'flipud', 'tri', 'triu',
#      20     'tril', 'vander', 'histogram2d', 'mask_indices', 'tril_indices',
#      21     'tril_indices_from', 'triu_indices', 'triu_indices_from', ]
#      24 array_function_dispatch = functools.partial(
#      25     overrides.array_function_dispatch, module='numpy')
#
# ImportError: cannot import name 'broadcast_to' from 'numpy.lib.stride_tricks' (/home/dorvan/Documents/dorvan/Babydoll/Produits/Babybot-01/Informatic-01/venv/jetsonEnv/lib/python3.10/site-packages/numpy/lib/stride_tricks.py)

# %%
env = gym.make("CartPole-v1", render_mode='human')

for e in range(3):

    obs, info = env.reset()

    while True:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

        if terminated or truncated:
            break
